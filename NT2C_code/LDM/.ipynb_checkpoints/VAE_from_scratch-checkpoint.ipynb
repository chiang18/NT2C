# %%
# %pip install accelerate -qq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 8.5 MB/s eta 0:00:00

# %%
# %pip install torchinfo -qq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import accelerate
from diffusers import AutoencoderKL
from torchinfo import summary

# %% [markdown]
# ### Load pretrained model

# %%
vae = AutoencoderKL.from_pretrained(
        "stabilityai/stable-diffusion-2-1", subfolder="vae"
    )

# %%
vae.encoder.conv_in.weight # Check the weights
# Out:
# Parameter containing:
# tensor([[[[-0.0163, -0.0705, -0.0105],
#           [-0.0400,  0.1914, -0.1305],
#           [-0.0598,  0.1802,  0.0539]],
#
#          [[-0.1353,  0.0731, -0.1355],
#           [ 0.1158,  0.0268, -0.0002],
#           [-0.0959, -0.1007, -0.0498]],
#
#          [[ 0.0004, -0.0772,  0.0819],
#           [-0.1118, -0.0585, -0.0917],
#           [ 0.0407, -0.1639,  0.1825]]],
#
#
#         [[[ 0.1442,  0.1639, -0.0937],
#           [ 0.0084, -0.0132, -0.0937],
#           [ 0.0699,  0.0554, -0.1498]],
#
#          [[ 0.0077, -0.1456,  0.0830],
#           [ 0.1338,  0.0247, -0.1826],
#           [-0.0516,  0.1406, -0.0797]],
#
#          [[ 0.0567, -0.1147,  0.0006],
#           [-0.0842, -0.1371, -0.0894],
#           [-0.0407,  0.2042,  0.1970]]],
#
#
#         [[[ 0.0627,  0.0862,  0.0405],
#           [-0.1047,  0.0573, -0.0354],
#           [-0.1557, -0.0617,  0.0760]],
#
#          [[-0.0525, -0.0289,  0.0229],
#           [ 0.0319, -0.1969, -0.1524],
#           [ 0.0663,  0.0997, -0.0925]],
#
#          [[ 0.0957,  0.0300,  0.1325],
#           [ 0.0654, -0.0341,  0.1281],
#           [-0.0995, -0.0431,  0.0367]]],
#
#
#         ...,
#
#
#         [[[-0.0674, -0.0425, -0.0853],
#           [ 0.1607, -0.1607, -0.1167],
#           [ 0.1785, -0.1898,  0.0432]],
#
#          [[ 0.0424,  0.1552,  0.1022],
#           [ 0.1430, -0.1392, -0.1355],
#           [ 0.1218,  0.1064,  0.1855]],
#
#          [[-0.0362, -0.0597,  0.1364],
#           [-0.1896,  0.1726, -0.1503],
#           [ 0.0958, -0.1051,  0.0441]]],
#
#
#         [[[-0.0142, -0.0729,  0.0181],
#           [-0.1437, -0.0446,  0.0545],
#           [ 0.0652, -0.1575, -0.1143]],
#
#          [[-0.0436,  0.0238,  0.0156],
#           [ 0.2195,  0.0372,  0.1562],
#           [ 0.0547,  0.0306, -0.1019]],
#
#          [[ 0.1404,  0.0613, -0.1215],
#           [-0.0539, -0.0502, -0.0324],
#           [-0.1646, -0.0116,  0.1283]]],
#
#
#         [[[ 0.1137,  0.0705,  0.1335],
#           [-0.1508, -0.0766,  0.1459],
#           [ 0.1884, -0.0943,  0.0687]],
#
#          [[ 0.0910, -0.1243,  0.0329],
#           [-0.0112, -0.1064, -0.0708],
#           [ 0.0494, -0.1794, -0.1695]],
#
#          [[-0.0232, -0.0617,  0.0379],
#           [ 0.1950,  0.0994, -0.1141],
#           [ 0.0518, -0.0742, -0.0496]]]], requires_grad=True)

# %%
summary(vae, input_size=(4, 3, 256, 256)) # It is pytorch model
# Out:
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# AutoencoderKL                                                [4, 3, 256, 256]          --
# ├─Encoder: 1-1                                               [4, 8, 32, 32]            33,421,064
# │    └─Conv2d: 2-1                                           [4, 128, 256, 256]        3,584
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-1                          [4, 128, 128, 128]        738,944
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-9                          --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-9                          --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-9                          --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-9                          --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-10                         [4, 256, 64, 64]          2,690,304
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-18                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-18                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-18                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-18                         --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-19                         [4, 512, 32, 32]          10,754,560
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-27                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-27                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-27                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-27                         --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-28                         [4, 512, 32, 32]          9,443,328
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-36                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-36                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-36                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-36                         --                        (recursive)
# │    └─UNetMidBlock2D: 2-35                                  [4, 512, 32, 32]          5,773,312
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-43                                  --                        (recursive)
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-43                                  --                        (recursive)
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# │    │    └─ModuleList: 3-42                                 --                        1,051,648
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-43                                  --                        (recursive)
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-43                                  --                        (recursive)
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# │    └─GroupNorm: 2-44                                       [4, 512, 32, 32]          1,024
# │    └─SiLU: 2-45                                            [4, 512, 32, 32]          --
# │    └─Conv2d: 2-46                                          [4, 8, 32, 32]            36,872
# ├─Conv2d: 1-42                                               [4, 8, 32, 32]            72
# ├─Conv2d: 1-43                                               [4, 4, 32, 32]            20
# ├─Decoder: 1-44                                              [4, 3, 256, 256]          --
# │    └─Conv2d: 2-47                                          [4, 512, 32, 32]          18,944
# │    └─UNetMidBlock2D: 2-48                                  [4, 512, 32, 32]          --
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    │    └─ModuleList: 3-49                                 --                        1,051,648
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-51                           [4, 512, 64, 64]          16,524,800
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-64                           [4, 512, 128, 128]        16,524,800
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-77                           [4, 256, 256, 256]        4,855,296
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-90                           [4, 128, 256, 256]        1,067,648
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─GroupNorm: 2-98                                       [4, 128, 256, 256]        256
# │    └─SiLU: 2-99                                            [4, 128, 256, 256]        --
# │    └─Conv2d: 2-100                                         [4, 3, 256, 256]          3,459
# ==============================================================================================================
# Total params: 232,356,335
# Trainable params: 232,356,335
# Non-trainable params: 0
# Total mult-adds (T): 1.77
# ==============================================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 12640.19
# Params size (MB): 334.62
# Estimated Total Size (MB): 12977.95
# ==============================================================================================================

# %%
vae.save_config("test") # Save the architecture

# %% [markdown]
# We can now check the `config.json` file under `test` directory

# %%
vae2 = AutoencoderKL() # Initialize the default model

# %%
vae2.encoder.conv_in.weight # Check the weights
# Out:
# Parameter containing:
# tensor([[[[ 1.1444e-01,  2.0141e-02,  1.8834e-01],
#           [ 1.0031e-01, -1.6630e-01,  3.6602e-02],
#           [ 6.7165e-03, -3.2538e-02, -5.1920e-02]],
#
#          [[-1.5622e-01,  2.1921e-02,  9.8316e-02],
#           [ 6.8307e-03,  6.9231e-02, -1.8934e-01],
#           [-1.0204e-01, -4.3917e-02, -1.1897e-01]],
#
#          [[-1.1075e-03,  1.8911e-01, -5.3249e-02],
#           [ 2.1096e-02,  1.1959e-01, -1.5373e-01],
#           [-8.5214e-02,  1.7628e-02, -1.1248e-01]]],
#
#
#         [[[-4.2449e-02,  1.9581e-03, -3.1201e-05],
#           [ 2.3503e-02, -9.5870e-02, -1.9742e-02],
#           [ 1.3290e-01, -9.4986e-02,  1.0837e-01]],
#
#          [[-1.1278e-02,  6.1400e-02,  1.7499e-01],
#           [ 1.4363e-01, -1.8135e-01,  6.2502e-02],
#           [ 4.0686e-02,  5.4634e-02, -1.2196e-01]],
#
#          [[-1.1464e-01, -1.1090e-01,  9.3882e-02],
#           [ 9.8902e-02,  1.7435e-01, -2.5746e-03],
#           [-1.3072e-01, -3.9491e-02,  1.2040e-01]]],
#
#
#         [[[ 1.6020e-01, -1.5984e-01,  1.6868e-01],
#           [ 2.7593e-02, -7.4067e-02, -4.5686e-02],
#           [-7.6040e-02,  1.5673e-01,  1.0844e-01]],
#
#          [[ 1.2440e-02,  6.9202e-02, -3.0957e-02],
#           [ 1.5422e-01,  1.5327e-01, -8.7853e-02],
#           [ 1.5229e-01,  3.1572e-03,  1.5392e-01]],
#
#          [[ 1.5148e-01, -6.4658e-02, -7.5466e-02],
#           [-1.4223e-01, -4.7961e-03, -9.6182e-02],
#           [ 1.4425e-01, -1.8392e-01,  1.7437e-01]]],
#
#
#         ...,
#
#
#         [[[-3.8390e-02,  1.2182e-02,  4.9992e-02],
#           [ 1.5950e-01,  1.8465e-01,  3.2632e-02],
#           [ 2.1248e-02,  1.6704e-01, -1.5092e-01]],
#
#          [[ 1.4257e-01, -6.4093e-03, -8.8292e-02],
#           [ 1.5827e-01, -1.6460e-01,  4.4581e-02],
#           [-1.1960e-01,  9.9255e-02,  1.4986e-01]],
#
#          [[ 2.5864e-02,  1.3219e-01, -1.3059e-01],
#           [-9.9870e-02,  1.4523e-01, -1.3325e-01],
#           [ 1.4929e-01,  5.4937e-02, -1.1469e-01]]],
#
#
#         [[[-1.3457e-01,  7.7140e-04,  2.8182e-02],
#           [ 5.1002e-02,  9.0302e-02,  1.0707e-02],
#           [-1.2976e-01,  1.3962e-01,  1.4532e-01]],
#
#          [[ 2.0073e-02, -1.5617e-01, -1.2860e-01],
#           [-1.0322e-01, -1.4989e-01,  1.6289e-01],
#           [-6.9558e-02,  1.6044e-02,  1.1233e-01]],
#
#          [[-7.9629e-02,  5.2558e-02, -1.2949e-01],
#           [-1.8072e-01, -7.2115e-02, -2.3397e-02],
#           [ 6.2725e-02, -1.0835e-01, -1.4857e-01]]],
#
#
#         [[[ 1.6698e-01,  1.8707e-01,  2.7476e-02],
#           [-1.0893e-01, -1.3497e-01, -2.3083e-02],
#           [-7.6481e-02, -7.6175e-03,  1.8951e-01]],
#
#          [[ 1.6884e-01,  6.5771e-02, -7.0495e-02],
#           [-1.1523e-01, -9.6329e-02,  5.2265e-02],
#           [ 7.7943e-02,  1.3393e-01, -8.7497e-02]],
#
#          [[ 1.4514e-02, -1.5555e-01, -1.3459e-01],
#           [ 2.8927e-02, -1.7472e-01, -9.8729e-02],
#           [-1.2179e-01, -8.2497e-02, -1.6958e-01]]]], requires_grad=True)

# %%
summary(vae2, input_size=(4, 3, 256, 256)) # It is pytorch model
# Out:
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# AutoencoderKL                                                [4, 3, 256, 256]          --
# ├─Encoder: 1-1                                               [4, 8, 256, 256]          169,736
# │    └─Conv2d: 2-1                                           [4, 64, 256, 256]         1,792
# │    └─ModuleList: 2-6                                       --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-1                          [4, 64, 256, 256]         74,112
# ├─Decoder: 1-12                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# ├─Encoder: 1-13                                              --                        (recursive)
# │    └─ModuleList: 2-6                                       --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-5                          --                        (recursive)
# ├─Decoder: 1-12                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# ├─Encoder: 1-13                                              --                        (recursive)
# │    └─ModuleList: 2-6                                       --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-5                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-7                                   [4, 64, 256, 256]         90,880
# │    │    └─ModuleList: 3-16                                 --                        (recursive)
# ├─Decoder: 1-12                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# ├─Encoder: 1-13                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-15                                  --                        (recursive)
# │    │    └─ModuleList: 3-16                                 --                        (recursive)
# ├─Decoder: 1-12                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# ├─Encoder: 1-13                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-15                                  --                        (recursive)
# │    │    └─ModuleList: 3-16                                 --                        (recursive)
# │    │    └─ModuleList: 3-11                                 --                        16,768
# │    │    └─ModuleList: 3-16                                 --                        (recursive)
# ├─Decoder: 1-12                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# ├─Encoder: 1-13                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-15                                  --                        (recursive)
# │    │    └─ModuleList: 3-16                                 --                        (recursive)
# ├─Decoder: 1-12                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# ├─Encoder: 1-13                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-15                                  --                        (recursive)
# │    │    └─ModuleList: 3-16                                 --                        (recursive)
# │    └─GroupNorm: 2-16                                       [4, 64, 256, 256]         128
# │    └─SiLU: 2-17                                            [4, 64, 256, 256]         --
# │    └─Conv2d: 2-18                                          [4, 8, 256, 256]          4,616
# ├─Conv2d: 1-14                                               [4, 8, 256, 256]          72
# ├─Conv2d: 1-15                                               [4, 4, 256, 256]          20
# ├─Decoder: 1-16                                              [4, 3, 256, 256]          --
# │    └─Conv2d: 2-19                                          [4, 64, 256, 256]         2,368
# │    └─UNetMidBlock2D: 2-20                                  [4, 64, 256, 256]         --
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# │    │    └─ModuleList: 3-18                                 --                        16,768
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# │    └─ModuleList: 2-29                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-20                           [4, 64, 256, 256]         148,224
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# │    └─ModuleList: 2-29                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-28                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# │    └─ModuleList: 2-29                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-28                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# │    └─ModuleList: 2-29                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-28                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-28                                  --                        (recursive)
# │    │    └─ModuleList: 3-27                                 --                        (recursive)
# │    └─ModuleList: 2-29                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-28                           --                        (recursive)
# │    └─GroupNorm: 2-30                                       [4, 64, 256, 256]         128
# │    └─SiLU: 2-31                                            [4, 64, 256, 256]         --
# │    └─Conv2d: 2-32                                          [4, 3, 256, 256]          1,731
# ==============================================================================================================
# Total params: 1,341,807
# Trainable params: 1,341,807
# Non-trainable params: 0
# Total mult-adds (G): 138.30
# ==============================================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 5685.38
# Params size (MB): 2.25
# Estimated Total Size (MB): 5690.78
# ==============================================================================================================

# %%
vae2.save_config("test2") # Save the architecture

# %% [markdown]
# We can now check the `config.json` file under `test2` directory

# %%
vae3 = AutoencoderKL.from_config(AutoencoderKL.load_config('test')) # Use the architecture from the first one

# %%
vae3.encoder.conv_in.weight # Check the weights
# Out:
# Parameter containing:
# tensor([[[[ 0.1236,  0.1924,  0.0269],
#           [ 0.0737,  0.0835,  0.1613],
#           [ 0.1328, -0.1876,  0.0786]],
#
#          [[ 0.0888, -0.0664, -0.0011],
#           [ 0.1719, -0.0332,  0.1778],
#           [ 0.0502, -0.1185, -0.0198]],
#
#          [[-0.0057,  0.1187,  0.0183],
#           [ 0.1618,  0.1642,  0.0572],
#           [ 0.0075,  0.1572, -0.1903]]],
#
#
#         [[[ 0.1057, -0.0743, -0.1531],
#           [ 0.0748,  0.0531,  0.1855],
#           [ 0.0678,  0.0870,  0.0323]],
#
#          [[ 0.1129, -0.0764,  0.1702],
#           [ 0.0039,  0.0302,  0.0916],
#           [-0.1901, -0.1794,  0.0379]],
#
#          [[-0.0382,  0.1779,  0.0485],
#           [-0.1332, -0.0265,  0.0078],
#           [-0.0969, -0.0329,  0.1236]]],
#
#
#         [[[ 0.0088,  0.1235, -0.0755],
#           [-0.1069, -0.1820, -0.0139],
#           [ 0.0180,  0.0201, -0.1633]],
#
#          [[ 0.1435, -0.1049,  0.1484],
#           [ 0.1690, -0.1582,  0.1541],
#           [-0.1300,  0.1822, -0.0530]],
#
#          [[ 0.0527,  0.1806, -0.1617],
#           [ 0.1842, -0.0368,  0.1449],
#           [ 0.1125, -0.0656, -0.0924]]],
#
#
#         ...,
#
#
#         [[[ 0.0451,  0.1567,  0.0024],
#           [ 0.1184, -0.0758, -0.0886],
#           [ 0.1475,  0.1802, -0.0097]],
#
#          [[-0.0833, -0.1000,  0.0372],
#           [-0.0063,  0.1401,  0.1778],
#           [-0.1352, -0.0662,  0.0212]],
#
#          [[-0.1667,  0.0429, -0.0831],
#           [ 0.0442, -0.1317, -0.0821],
#           [ 0.0883, -0.1248,  0.1492]]],
#
#
#         [[[ 0.1066, -0.1156, -0.0036],
#           [-0.0649, -0.1907,  0.1793],
#           [-0.0694,  0.0165,  0.0085]],
#
#          [[ 0.0879,  0.0320, -0.0182],
#           [-0.0903, -0.1688, -0.0878],
#           [-0.0991,  0.1080,  0.1236]],
#
#          [[-0.1406, -0.0596, -0.0930],
#           [-0.0962,  0.1521, -0.1218],
#           [ 0.1646,  0.0155, -0.1124]]],
#
#
#         [[[ 0.0849,  0.1891, -0.1873],
#           [ 0.0265, -0.1760,  0.0704],
#           [-0.0682,  0.1240, -0.0860]],
#
#          [[ 0.1740, -0.1752, -0.1902],
#           [ 0.1333, -0.1680, -0.0687],
#           [ 0.0890, -0.1380, -0.0635]],
#
#          [[-0.1521,  0.1331,  0.1496],
#           [-0.1380,  0.1604,  0.1669],
#           [ 0.1628, -0.1168, -0.0959]]]], requires_grad=True)

# %%
summary(vae3, input_size=(4, 3, 256, 256)) # It is pytorch model
# Out:
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# AutoencoderKL                                                [4, 3, 256, 256]          --
# ├─Encoder: 1-1                                               [4, 8, 32, 32]            33,421,064
# │    └─Conv2d: 2-1                                           [4, 128, 256, 256]        3,584
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-1                          [4, 128, 128, 128]        738,944
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-9                          --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-9                          --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-9                          --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-9                          --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-10                         [4, 256, 64, 64]          2,690,304
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-18                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-18                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-18                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-18                         --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-19                         [4, 512, 32, 32]          10,754,560
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-27                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-27                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-27                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-27                         --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-28                         [4, 512, 32, 32]          9,443,328
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-36                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-36                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-36                         --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─ModuleList: 2-34                                      --                        (recursive)
# │    │    └─DownEncoderBlock2D: 3-36                         --                        (recursive)
# │    └─UNetMidBlock2D: 2-35                                  [4, 512, 32, 32]          5,773,312
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-43                                  --                        (recursive)
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-43                                  --                        (recursive)
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# │    │    └─ModuleList: 3-42                                 --                        1,051,648
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-43                                  --                        (recursive)
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# ├─Decoder: 1-40                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# ├─Encoder: 1-41                                              --                        (recursive)
# │    └─UNetMidBlock2D: 2-43                                  --                        (recursive)
# │    │    └─ModuleList: 3-47                                 --                        (recursive)
# │    └─GroupNorm: 2-44                                       [4, 512, 32, 32]          1,024
# │    └─SiLU: 2-45                                            [4, 512, 32, 32]          --
# │    └─Conv2d: 2-46                                          [4, 8, 32, 32]            36,872
# ├─Conv2d: 1-42                                               [4, 8, 32, 32]            72
# ├─Conv2d: 1-43                                               [4, 4, 32, 32]            20
# ├─Decoder: 1-44                                              [4, 3, 256, 256]          --
# │    └─Conv2d: 2-47                                          [4, 512, 32, 32]          18,944
# │    └─UNetMidBlock2D: 2-48                                  [4, 512, 32, 32]          --
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    │    └─ModuleList: 3-49                                 --                        1,051,648
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-51                           [4, 512, 64, 64]          16,524,800
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-63                           --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-64                           [4, 512, 128, 128]        16,524,800
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-76                           --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-77                           [4, 256, 256, 256]        4,855,296
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-89                           --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-90                           [4, 128, 256, 256]        1,067,648
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─UNetMidBlock2D: 2-96                                  --                        (recursive)
# │    │    └─ModuleList: 3-101                                --                        (recursive)
# │    └─ModuleList: 2-97                                      --                        (recursive)
# │    │    └─UpDecoderBlock2D: 3-102                          --                        (recursive)
# │    └─GroupNorm: 2-98                                       [4, 128, 256, 256]        256
# │    └─SiLU: 2-99                                            [4, 128, 256, 256]        --
# │    └─Conv2d: 2-100                                         [4, 3, 256, 256]          3,459
# ==============================================================================================================
# Total params: 232,356,335
# Trainable params: 232,356,335
# Non-trainable params: 0
# Total mult-adds (T): 1.77
# ==============================================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 12640.19
# Params size (MB): 334.62
# Estimated Total Size (MB): 12977.95
# ==============================================================================================================
